# %%
import csv

FY_14_FILE_NAMES=['fy14_ak.csv','fy14_al.csv','fy14_ar.csv','fy14_az.csv','fy14_ca.csv','fy14_co.csv','fy14_ct.csv',
                  'fy14_dc.csv','fy14_de.csv','fy14_fl.csv','fy14_ga.csv','fy14_gu.csv','fy14_hi.csv','fy14_ia.csv',
                  'fy14_id.csv','fy14_il.csv','fy14_in.csv','fy14_ks.csv','fy14_ky.csv','fy14_la.csv','fy14_ma.csv',
                  'fy14_md.csv','fy14_me.csv','fy14_mi.csv','fy14_mn.csv','fy14_mo.csv','fy14_ms.csv','fy14_mt.csv',
                  'fy14_nc.csv','fy14_nd.csv','fy14_ne.csv','fy14_nh.csv','fy14_nj.csv','fy14_nm.csv','fy14_nv.csv',
                  'fy14_ny.csv','fy14_oh.csv','fy14_ok.csv','fy14_or.csv','fy14_pa.csv','fy14_pr.csv','fy14_ri.csv',
                  'fy14_sc.csv','fy14_sd.csv','fy14_tn.csv','fy14_tx.csv','fy14_ut.csv','fy14_va.csv','fy14_vt.csv',
                  'fy14_wa.csv','fy14_wi.csv','fy14_wv.csv','fy14_wy.csv']
FY_15_FILE_NAMES=['fy15_ak.csv','fy15_al.csv','fy15_ar.csv','fy15_az.csv','fy15_ca.csv','fy15_co.csv','fy15_ct.csv',
                  'fy15_dc.csv','fy15_de.csv','fy15_fl.csv','fy15_ga.csv','fy15_gu.csv','fy15_hi.csv','fy15_ia.csv',
                  'fy15_id.csv','fy15_il.csv','fy15_in.csv','fy15_ks.csv','fy15_ky.csv','fy15_la.csv','fy15_ma.csv',
                  'fy15_md.csv','fy15_me.csv','fy15_mi.csv','fy15_mn.csv','fy15_mo.csv','fy15_ms.csv','fy15_mt.csv',
                  'fy15_nc.csv','fy15_nd.csv','fy15_ne.csv','fy15_nh.csv','fy15_nj.csv','fy15_nm.csv','fy15_nv.csv',
                  'fy15_ny.csv','fy15_oh.csv','fy15_ok.csv','fy15_or.csv','fy15_pa.csv','fy15_pr.csv','fy15_ri.csv',
                  'fy15_sc.csv','fy15_sd.csv','fy15_tn.csv','fy15_tx.csv','fy15_ut.csv','fy15_va.csv','fy15_vt.csv',
                  'fy15_wa.csv','fy15_wi.csv','fy15_wv.csv','fy15_wy.csv']
FY_16_FILE_NAMES=['fy16_ak.csv','fy16_al.csv','fy16_ar.csv','fy16_az.csv','fy16_ca.csv','fy16_co.csv','fy16_ct.csv',
                  'fy16_dc.csv','fy16_de.csv','fy16_fl.csv','fy16_ga.csv','fy16_gu.csv','fy16_hi.csv','fy16_ia.csv',
                  'fy16_id.csv','fy16_il.csv','fy16_in.csv','fy16_ks.csv','fy16_ky.csv','fy16_la.csv','fy16_ma.csv',
                  'fy16_md.csv','fy16_me.csv','fy16_mi.csv','fy16_mn.csv','fy16_mo.csv','fy16_ms.csv','fy16_mt.csv',
                  'fy16_nc.csv','fy16_nd.csv','fy16_ne.csv','fy16_nh.csv','fy16_nj.csv','fy16_nm.csv','fy16_nv.csv',
                  'fy16_ny.csv','fy16_oh.csv','fy16_ok.csv','fy16_or.csv','fy16_pa.csv','fy16_pr.csv','fy16_ri.csv',
                  'fy16_sc.csv','fy16_sd.csv','fy16_tn.csv','fy16_tx.csv','fy16_ut.csv','fy16_va.csv','fy16_vt.csv',
                  'fy16_wa.csv','fy16_wi.csv','fy16_wv.csv','fy16_wy.csv']

STATE_NAMES=['Alaska','Alabama','Arkansas','Arizona','California','Colorado','Connecticut','DC','Delaware','Florida',
            'Georgia','Guam','Hawaii','Iowa','Idaho','Illinois','Indiana','Kansas','Kentucky','Louisiana','Massachusetts',
            'Maryland', 'Maine','Michigan','Missouri','Mississippi','Montana','North Carolina','North Dakota','Nebraska',
            'New Hampshire','New Jersey','New Mexico','Nevada','New York','Ohio','Oklahoma','Oregon','Pennsylvania',
            'Puerto Rico','Rhode Island','South Carolina','South Dakota','Tennessee','Texas','Utah','Virginia','Vermont',
            'Washington','Wisconsin','West Virginia','Wyoming']

FY_14_VETS_PER_STATE=[]
FY_15_VETS_PER_STATE=[]
FY_16_VETS_PER_STATE=[]

FY_14_DOLLARS_PER_STATE=[]
FY_15_DOLLARS_PER_STATE=[]
FY_16_DOLLARS_PER_STATE=[]

FY_14_VET_POP=0
FY_15_VET_POP=0
FY_16_VET_POP=0

FY_14_COMPENSATION=0
FY_15_COMPENSATION=0
FY_16_COMPENSATION=0

FY_14_EDUCATION=0
FY_15_EDUCATION=0
FY_16_EDUCATION=0

FY_14_INSURANCE=0
FY_15_INSURANCE=0
FY_16_INSURANCE=0

FY_14_MEDICAL=0
FY_15_MEDICAL=0
FY_16_MEDICAL=0

FY_14_RATIO_PER_STATE=[]
FY_15_RATIO_PER_STATE=[]
FY_16_RATIO_PER_STATE=[]

#read from file row by row
#if row[2]=STATE NAME then gather the following
#    column 3, 5, 7, 10, 11

def gatherInfo14(fname, state_name):
    global FY_14_VETS_PER_STATE
    global FY_14_DOLLARS_PER_STATE
    global FY_14_VET_POP    
    global FY_14_COMPENSATION    
    global FY_14_EDUCATION    
    global FY_14_INSURANCE    
    global FY_14_MEDICAL
    
    with open(fname, 'r') as f:
        reader = csv.reader(f)#1
        for row in reader:
            if '(Totals)' in str(row[2]):
                vets=row[3].replace(',', '')
                bens_1=row[5].replace(',','')
                bens_1=bens_1.replace('$','')
                bens_2=row[7].replace(',','')
                bens_2=bens_2.replace('$','')
                bens_3=row[10].replace(',','')
                bens_3=bens_3.replace('$','')
                bens_4=row[11].replace(',','')
                bens_4=bens_4.replace('$','')
            
                FY_14_VETS_PER_STATE.append(int(vets))#1
                Dollars_spent_benefits=float(bens_1)+float(bens_2)+float(bens_3)+float(bens_4)
                FY_14_DOLLARS_PER_STATE.append(Dollars_spent_benefits)#2
                
                FY_14_VET_POP=FY_14_VET_POP+int(vets)#4
                FY_14_COMPENSATION=FY_14_COMPENSATION+float(bens_1)#5
                FY_14_EDUCATION=FY_14_EDUCATION+float(bens_2)#5
                FY_14_INSURANCE=FY_14_INSURANCE+float(bens_3)#5
                FY_14_MEDICAL=FY_14_MEDICAL+float(bens_4)#5
                break
    return 0

def gatherInfo15(fname, state_name):
    global FY_15_VETS_PER_STATE
    global FY_15_DOLLARS_PER_STATE
    global FY_15_VET_POP
    global FY_15_COMPENSATION
    global FY_15_EDUCATION
    global FY_15_INSURANCE
    global FY_15_MEDICAL

    with open(fname, 'r') as f:
        reader = csv.reader(f)#2
        for row in reader:            
            if '(Totals)' in str(row[2]):
                vets=row[3].replace(',', '')
                bens_1=row[5].replace(',','')
                bens_1=bens_1.replace('$','')
                bens_2=row[7].replace(',','')
                bens_2=bens_2.replace('$','')
                bens_3=row[10].replace(',','')
                bens_3=bens_3.replace('$','')
                bens_4=row[11].replace(',','')
                bens_4=bens_4.replace('$','')
                
                FY_15_VETS_PER_STATE.append(int(vets))#1
                Dollars_spent_benefits=float(bens_1)+float(bens_2)+float(bens_3)+float(bens_4)
                FY_15_DOLLARS_PER_STATE.append(Dollars_spent_benefits)#2
    
                FY_15_VET_POP=FY_15_VET_POP+int(vets)#4
                FY_15_COMPENSATION=FY_15_COMPENSATION+float(bens_1)#5
                FY_15_EDUCATION=FY_15_EDUCATION+float(bens_2)#5
                FY_15_INSURANCE=FY_15_INSURANCE+float(bens_3)#5
                FY_15_MEDICAL=FY_15_MEDICAL+float(bens_4)#5
                break
            
    return 0
                
def gatherInfo16(fname, state_name):
    global FY_16_DOLLARS_PER_STATE
    global FY_16_VETS_PER_STATE
    global FY_16_VET_POP
    global FY_16_COMPENSATION
    global FY_16_EDUCATION
    global FY_16_INSURANCE
    global FY_16_MEDICAL
    
    with open(fname, 'r') as f:
        reader = csv.reader(f)#3
        for row in reader:
            if '(Totals)' in str(row[2]):
                vets=row[3].replace(',', '')
                bens_1=row[5].replace(',','')
                bens_1=bens_1.replace('$','')
                bens_2=row[7].replace(',','')
                bens_2=bens_2.replace('$','')
                bens_3=row[10].replace(',','')
                bens_3=bens_3.replace('$','')
                bens_4=row[11].replace(',','')
                bens_4=bens_4.replace('$','')
                
                FY_16_VETS_PER_STATE.append(int(vets))#1
                Dollars_spent_benefits=float(bens_1)+float(bens_2)+float(bens_3)+float(bens_4)
                FY_16_DOLLARS_PER_STATE.append(Dollars_spent_benefits)#2
    
                FY_16_VET_POP=FY_16_VET_POP+int(vets)#4
                FY_16_COMPENSATION=FY_16_COMPENSATION+float(bens_1)#5
                FY_16_EDUCATION=FY_16_EDUCATION+float(bens_2)#5
                FY_16_INSURANCE=FY_16_INSURANCE+float(bens_3)#5
                FY_16_MEDICAL=FY_16_MEDICAL+float(bens_4)#5
                break
    return 0

if __name__=="__main__":
    
    global FY_14_RATIO_PER_STATE
    global FY_15_RATIO_PER_STATE
    global FY_16_RATIO_PER_STATE
    
    FY_14_FILE_NAMES=['fy14_ak.csv','fy14_al.csv','fy14_ar.csv','fy14_az.csv','fy14_ca.csv','fy14_co.csv','fy14_ct.csv',
                  'fy14_dc.csv','fy14_de.csv','fy14_fl.csv','fy14_ga.csv','fy14_gu.csv','fy14_hi.csv','fy14_ia.csv',
                  'fy14_id.csv','fy14_il.csv','fy14_in.csv','fy14_ks.csv','fy14_ky.csv','fy14_la.csv','fy14_ma.csv',
                  'fy14_md.csv','fy14_me.csv','fy14_mi.csv','fy14_mn.csv','fy14_mo.csv','fy14_ms.csv','fy14_mt.csv',
                  'fy14_nc.csv','fy14_nd.csv','fy14_ne.csv','fy14_nh.csv','fy14_nj.csv','fy14_nm.csv','fy14_nv.csv',
                  'fy14_ny.csv','fy14_oh.csv','fy14_ok.csv','fy14_or.csv','fy14_pa.csv','fy14_pr.csv','fy14_ri.csv',
                  'fy14_sc.csv','fy14_sd.csv','fy14_tn.csv','fy14_tx.csv','fy14_ut.csv','fy14_va.csv','fy14_vt.csv',
                  'fy14_wa.csv','fy14_wi.csv','fy14_wv.csv','fy14_wy.csv']
    FY_15_FILE_NAMES=['fy15_ak.csv','fy15_al.csv','fy15_ar.csv','fy15_az.csv','fy15_ca.csv','fy15_co.csv','fy15_ct.csv',
                  'fy15_dc.csv','fy15_de.csv','fy15_fl.csv','fy15_ga.csv','fy15_gu.csv','fy15_hi.csv','fy15_ia.csv',
                  'fy15_id.csv','fy15_il.csv','fy15_in.csv','fy15_ks.csv','fy15_ky.csv','fy15_la.csv','fy15_ma.csv',
                  'fy15_md.csv','fy15_me.csv','fy15_mi.csv','fy15_mn.csv','fy15_mo.csv','fy15_ms.csv','fy15_mt.csv',
                  'fy15_nc.csv','fy15_nd.csv','fy15_ne.csv','fy15_nh.csv','fy15_nj.csv','fy15_nm.csv','fy15_nv.csv',
                  'fy15_ny.csv','fy15_oh.csv','fy15_ok.csv','fy15_or.csv','fy15_pa.csv','fy15_pr.csv','fy15_ri.csv',
                  'fy15_sc.csv','fy15_sd.csv','fy15_tn.csv','fy15_tx.csv','fy15_ut.csv','fy15_va.csv','fy15_vt.csv',
                  'fy15_wa.csv','fy15_wi.csv','fy15_wv.csv','fy15_wy.csv']
    FY_16_FILE_NAMES=['fy16_ak.csv','fy16_al.csv','fy16_ar.csv','fy16_az.csv','fy16_ca.csv','fy16_co.csv','fy16_ct.csv',
                  'fy16_dc.csv','fy16_de.csv','fy16_fl.csv','fy16_ga.csv','fy16_gu.csv','fy16_hi.csv','fy16_ia.csv',
                  'fy16_id.csv','fy16_il.csv','fy16_in.csv','fy16_ks.csv','fy16_ky.csv','fy16_la.csv','fy16_ma.csv',
                  'fy16_md.csv','fy16_me.csv','fy16_mi.csv','fy16_mn.csv','fy16_mo.csv','fy16_ms.csv','fy16_mt.csv',
                  'fy16_nc.csv','fy16_nd.csv','fy16_ne.csv','fy16_nh.csv','fy16_nj.csv','fy16_nm.csv','fy16_nv.csv',
                  'fy16_ny.csv','fy16_oh.csv','fy16_ok.csv','fy16_or.csv','fy16_pa.csv','fy16_pr.csv','fy16_ri.csv',
                  'fy16_sc.csv','fy16_sd.csv','fy16_tn.csv','fy16_tx.csv','fy16_ut.csv','fy16_va.csv','fy16_vt.csv',
                  'fy16_wa.csv','fy16_wi.csv','fy16_wv.csv','fy16_wy.csv']
    STATE_NAMES=['Alaska','Alabama','Arkansas','Arizona','California','Colorado','Connecticut',
                 'DC','Delaware','Florida','Georgia','Guam','Hawaii','Iowa',
                 'Idaho','Illinois','Indiana','Kansas','Kentucky','Louisiana','Maine',
                 'Massachusetts','Maryland', 'Maine','Michigan','Missouri','Mississippi','Montana',
                 'North Carolina','North Dakota','Nebraska','New Hampshire','New Jersey','New Mexico','Nevada',
                 'New York','Ohio','Oklahoma','Oregon','Pennsylvania','Puerto Rico','Rhode Island',
                 'South Carolina','South Dakota','Tennessee','Texas','Utah','Virginia','Vermont',
                 'Washington','Wisconsin','West Virginia','Wyoming']
    
    #I WANT HISTOGRAMS OF
        #1. Ratio of dollars spent on a benefit per veteran per FY -FY_X_BEN/FY_X_VET_POP -> 3 'grams
        #2. Ratio of dollars spent per state on benefits to total dollars spent on benefits -FY_X_BEN/FY_X_DOLLARS_PER_STATE -> 3 'grams
        #3. Ratio of dollars spent per state on benefits per veteran per FY -FY_X_DOLLARS_PER_STATE/FY_X_VET_PER_STATE -> 3 'grams
    
    ##################################
    #      FISCAL YEAR 14 DATA       #
    ##################################
    i=0
    for file_name in FY_14_FILE_NAMES:
        state_name=STATE_NAMES[i]
        gatherInfo14(file_name, state_name)
        i=i+1  
    for x in range(0,53):
        ratio=float(FY_14_DOLLARS_PER_STATE[x]/FY_14_VETS_PER_STATE[x])
        FY_14_RATIO_PER_STATE.append(ratio) #HISTOGRAM 3
    
    #HISTOGRAM 1 -- FY_14_BEN/FY_14_VET_POP
    ratio=float(FY_14_COMPENSATION)/FY_14_VET_POP
    FY_14_COMP_PER_VET=ratio
    
    ratio=float(FY_14_EDUCATION)/FY_14_VET_POP
    FY_14_ED_PER_VET=ratio
    
    ratio=float(FY_14_INSURANCE)/FY_14_VET_POP
    FY_14_IN_PER_VET=ratio
    
    ratio=float(FY_14_MEDICAL)/FY_14_VET_POP
    FY_14_MED_PER_VET=ratio
    
    FY_14_BEN_PER_VET=[FY_14_COMP_PER_VET, FY_14_ED_PER_VET, FY_14_IN_PER_VET, FY_14_MED_PER_VET]
    
    #HISTOGRAM 2 -- FY_14_BEN/FY_14_DOLLARS_ON_BENEFITS
    FY_14_DOLLARS_ON_BENEFITS=FY_14_COMPENSATION+FY_14_EDUCATION+FY_14_INSURANCE+FY_14_MEDICAL
    
    ratio=float(FY_14_COMPENSATION)/FY_14_DOLLARS_ON_BENEFITS
    FY_14_COMP_OVER_TOTAL=ratio
    
    ratio=float(FY_14_EDUCATION)/FY_14_DOLLARS_ON_BENEFITS
    FY_14_ED_OVER_TOTAL=ratio
    
    ratio=float(FY_14_INSURANCE)/FY_14_DOLLARS_ON_BENEFITS
    FY_14_IN_OVER_TOTAL=ratio
    
    ratio=float(FY_14_MEDICAL)/FY_14_DOLLARS_ON_BENEFITS
    FY_14_MED_OVER_TOTAL=ratio
    
    FY_14_BEN_OVER_TOTAL=[FY_14_COMP_OVER_TOTAL, FY_14_ED_OVER_TOTAL, FY_14_IN_OVER_TOTAL, FY_14_MED_OVER_TOTAL]

    ##################################
    #      FISCAL YEAR 15 DATA       #
    ##################################
    i=0   
    for file_name in FY_15_FILE_NAMES:
        state_name=STATE_NAMES[i]
        gatherInfo15(file_name, state_name)
        i=i+1  
    for x in range(0,53):
        ratio=float(FY_15_DOLLARS_PER_STATE[x]/FY_15_VETS_PER_STATE[x])
        FY_15_RATIO_PER_STATE.append(ratio) #HISTOGRAM 3
        
    #HISTOGRAM 1 -- FY_15_BEN/FY_15_VET_POP
    ratio=float(FY_15_COMPENSATION)/FY_15_VET_POP
    FY_15_COMP_PER_VET=ratio
    
    ratio=float(FY_15_EDUCATION)/FY_15_VET_POP
    FY_15_ED_PER_VET=ratio
    
    ratio=float(FY_15_INSURANCE)/FY_15_VET_POP
    FY_15_IN_PER_VET=ratio
    
    ratio=float(FY_15_MEDICAL)/FY_15_VET_POP
    FY_15_MED_PER_VET=ratio
    
    FY_15_BEN_PER_VET=[FY_15_COMP_PER_VET, FY_15_ED_PER_VET, FY_15_IN_PER_VET, FY_15_MED_PER_VET]

    #HISTOGRAM 2 -- FY_14_BEN/FY_14_DOLLARS_ON_BENEFITS
    FY_15_DOLLARS_ON_BENEFITS=FY_15_COMPENSATION+FY_15_EDUCATION+FY_15_INSURANCE+FY_15_MEDICAL
    
    ratio=float(FY_15_COMPENSATION)/FY_15_DOLLARS_ON_BENEFITS
    FY_15_COMP_OVER_TOTAL=ratio
    
    ratio=float(FY_15_EDUCATION)/FY_15_DOLLARS_ON_BENEFITS
    FY_15_ED_OVER_TOTAL=ratio
    
    ratio=float(FY_15_INSURANCE)/FY_15_DOLLARS_ON_BENEFITS
    FY_15_IN_OVER_TOTAL=ratio
    
    ratio=float(FY_15_MEDICAL)/FY_15_DOLLARS_ON_BENEFITS
    FY_15_MED_OVER_TOTAL=ratio
    
    FY_15_BEN_OVER_TOTAL=[FY_15_COMP_OVER_TOTAL, FY_15_ED_OVER_TOTAL, FY_15_IN_OVER_TOTAL, FY_15_MED_OVER_TOTAL]

    ##################################
    #      FISCAL YEAR 16 DATA       #
    ##################################
    i=0
    for file_name in FY_16_FILE_NAMES:
        state_name=STATE_NAMES[i]
        gatherInfo16(file_name, state_name)
        i=i+1  
    for x in range(0,53):
        ratio=float(FY_16_DOLLARS_PER_STATE[x]/FY_16_VETS_PER_STATE[x])
        FY_16_RATIO_PER_STATE.append(ratio)
        
    #HISTOGRAM 1 -- FY_14_BEN/FY_14_VET_POP
    ratio=float(FY_16_COMPENSATION)/FY_16_VET_POP
    FY_16_COMP_PER_VET=ratio
    
    ratio=float(FY_16_EDUCATION)/FY_16_VET_POP
    FY_16_ED_PER_VET=ratio
    
    ratio=float(FY_16_INSURANCE)/FY_16_VET_POP
    FY_16_IN_PER_VET=ratio
    
    ratio=float(FY_16_MEDICAL)/FY_16_VET_POP
    FY_16_MED_PER_VET=ratio
    
    FY_16_BEN_PER_VET=[FY_16_COMP_PER_VET, FY_16_ED_PER_VET, FY_16_IN_PER_VET, FY_16_MED_PER_VET]

    #HISTOGRAM 2 -- FY_14_BEN/FY_14_DOLLARS_ON_BENEFITS
    FY_16_DOLLARS_ON_BENEFITS=FY_16_COMPENSATION+FY_16_EDUCATION+FY_16_INSURANCE+FY_16_MEDICAL
    
    ratio=float(FY_16_COMPENSATION)/FY_16_DOLLARS_ON_BENEFITS
    FY_16_COMP_OVER_TOTAL=ratio
    
    ratio=float(FY_16_EDUCATION)/FY_16_DOLLARS_ON_BENEFITS
    FY_16_ED_OVER_TOTAL=ratio
    
    ratio=float(FY_16_INSURANCE)/FY_16_DOLLARS_ON_BENEFITS
    FY_16_IN_OVER_TOTAL=ratio
    
    ratio=float(FY_16_MEDICAL)/FY_16_DOLLARS_ON_BENEFITS
    FY_16_MED_OVER_TOTAL=ratio
    
    FY_16_BEN_OVER_TOTAL=[FY_16_COMP_OVER_TOTAL, FY_16_ED_OVER_TOTAL, FY_16_IN_OVER_TOTAL, FY_16_MED_OVER_TOTAL]

    ###########################
    # WRITE ALL INFO TO CSV'S #
    ###########################
    #FY14
    FY14_BEN_PER=['FY_14_COMP_PER_VET', 'FY_14_ED_PER_VET', 'FY_14_IN_PER_VET', 'FY_14_MED_PER_VET']
    FY14_BEN_TOTAL=['FY_14_COMP_OVER_TOTAL', 'FY_14_ED_OVER_TOTAL', 'FY_14_IN_OVER_TOTAL', 'FY_14_MED_OVER_TOTAL']
    with open('FY_14_BEN_PER_VET.csv', 'w') as f:
        writer = csv.writer(f)
        writer.writerow(["Benefit", "Spent"])
        for x in range (0, 4):
            writer.writerow([FY14_BEN_PER[x], FY_14_BEN_PER_VET[x]])
        
    with open('FY_14_BEN_OVER_TOTAL.csv', 'w') as f:
        writer = csv.writer(f)
        writer.writerow(["Benefit", "Ratio"])
        for x in range (0, 4):
            writer.writerow([FY14_BEN_TOTAL[x], FY_14_BEN_OVER_TOTAL[x]])
        
    with open('FY_14_RATIO_PER_STATE.csv', 'w') as f:
        writer = csv.writer(f)
        writer.writerow(["State", "Ratio"])
        for x in range (0, 53):
            writer.writerow([STATE_NAMES[x], FY_14_RATIO_PER_STATE[x]])
        
    #FY15
    FY15_BEN_PER=['FY_15_COMP_PER_VET', 'FY_15_ED_PER_VET', 'FY_15_IN_PER_VET', 'FY_15_MED_PER_VET']
    FY15_BEN_TOTAL=['FY_15_COMP_OVER_TOTAL', 'FY_15_ED_OVER_TOTAL', 'FY_15_IN_OVER_TOTAL', 'FY_15_MED_OVER_TOTAL']
    with open('FY_15_BEN_PER_VET.csv', 'w') as f:
        writer = csv.writer(f)
        writer.writerow(["Benefit", "Spent"])
        for x in range (0,4):
            writer.writerow([FY15_BEN_PER[x],FY_15_BEN_PER_VET[x]])
        
    with open('FY_15_BEN_OVER_TOTAL.csv', 'w') as f:
        writer = csv.writer(f)
        writer.writerow(["Benefit", "Ratio"])
        for x in range (0,4):
            writer.writerow([FY15_BEN_TOTAL[x],FY_15_BEN_OVER_TOTAL[x]])
        
    with open('FY_15_RATIO_PER_STATE.csv', 'w') as f:
        writer = csv.writer(f)
        writer.writerow(["State", "Ratio"])
        for x in range(0,53):
            writer.writerow([STATE_NAMES[x],FY_15_RATIO_PER_STATE[x]])
        
    #FY16
    FY16_BEN_PER=['FY_16_COMP_PER_VET', 'FY_16_ED_PER_VET', 'FY_16_IN_PER_VET', 'FY_16_MED_PER_VET']
    FY16_BEN_TOTAL=['FY_16_COMP_OVER_TOTAL', 'FY_16_ED_OVER_TOTAL', 'FY_16_IN_OVER_TOTAL', 'FY_16_MED_OVER_TOTAL']
    with open('FY_16_BEN_PER_VET.csv', 'w') as f:
        writer = csv.writer(f)
        writer.writerow(["Benefit", "Spent"])
        for x in range(0,4):
            writer.writerow([FY16_BEN_PER[x],FY_16_BEN_PER_VET[x]])
        
    with open('FY_16_BEN_OVER_TOTAL.csv', 'w') as f:
        writer = csv.writer(f)
        writer.writerow(["Benefit", "Ratio"])
        for x in range(0,4):
            writer.writerow([FY16_BEN_TOTAL[x],FY_16_BEN_OVER_TOTAL[x]])
        
    with open('FY_16_RATIO_PER_STATE.csv', 'w') as f:
        writer = csv.writer(f)
        writer.writerow(["State", "Ratio"])
        for x in range(0,53):
            writer.writerow([STATE_NAMES[x], FY_16_RATIO_PER_STATE[x]])
        
    print("SCRIPT COMPLETED")
# Out:
# SCRIPT COMPLETED
