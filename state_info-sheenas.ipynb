# %% [markdown]
# State Data Sheena's Copy

# %%
import numpy as np
import pandas as pd
import matplotlib.pylab as plt 
# %matplotlib inline

# %%
fy14_ak = pd.read_csv('fy14_ak.csv')
fy14_al = pd.read_csv('fy14_al.csv')
fy14_ar = pd.read_csv('fy14_ar.csv')
fy14_az = pd.read_csv('fy14_az.csv')
fy14_ca = pd.read_csv('fy14_ca.csv')
fy14_co = pd.read_csv('fy14_co.csv')
fy14_ct = pd.read_csv('fy14_ct.csv')
fy14_dc = pd.read_csv('fy14_dc.csv')
fy14_de = pd.read_csv('fy14_de.csv')
fy14_fl = pd.read_csv('fy14_fl.csv')
fy14_ga = pd.read_csv('fy14_ga.csv')
fy14_gu = pd.read_csv('fy14_gu.csv')
fy14_hi = pd.read_csv('fy14_hi.csv')
fy14_ia = pd.read_csv('fy14_ia.csv')
fy14_id = pd.read_csv('fy14_id.csv')
fy14_il = pd.read_csv('fy14_il.csv')
fy14_in = pd.read_csv('fy14_in.csv')
fy14_ks = pd.read_csv('fy14_ks.csv')
fy14_ky = pd.read_csv('fy14_ky.csv')
fy14_la = pd.read_csv('fy14_la.csv')
fy14_ma = pd.read_csv('fy14_ma.csv')
fy14_md = pd.read_csv('fy14_md.csv')
fy14_me = pd.read_csv('fy14_me.csv')
fy14_mi = pd.read_csv('fy14_mi.csv')
fy14_mn = pd.read_csv('fy14_mn.csv')
fy14_mo = pd.read_csv('fy14_mo.csv')
fy14_ms = pd.read_csv('fy14_ms.csv')
fy14_mt = pd.read_csv('fy14_mt.csv')
fy14_nc = pd.read_csv('fy14_nc.csv')
fy14_nd = pd.read_csv('fy14_nd.csv')
fy14_ne = pd.read_csv('fy14_ne.csv')
fy14_nh = pd.read_csv('fy14_nh.csv')
fy14_nj = pd.read_csv('fy14_nj.csv')
fy14_nm = pd.read_csv('fy14_nm.csv')
fy14_nv = pd.read_csv('fy14_nv.csv')
fy14_ny = pd.read_csv('fy14_ny.csv')
fy14_oh = pd.read_csv('fy14_oh.csv')
fy14_ok = pd.read_csv('fy14_ok.csv')
fy14_or = pd.read_csv('fy14_or.csv')
fy14_pa = pd.read_csv('fy14_pa.csv')
fy14_pr = pd.read_csv('fy14_pr.csv')
fy14_ri = pd.read_csv('fy14_ri.csv')
fy14_sc = pd.read_csv('fy14_sc.csv')
fy14_sd = pd.read_csv('fy14_sd.csv')
fy14_tn = pd.read_csv('fy14_tn.csv')
fy14_tx = pd.read_csv('fy14_tx.csv')
fy14_ut = pd.read_csv('fy14_ut.csv')
fy14_va = pd.read_csv('fy14_va.csv')
fy14_vt = pd.read_csv('fy14_vt.csv')
fy14_wa = pd.read_csv('fy14_wa.csv')
fy14_wi = pd.read_csv('fy14_wi.csv')
fy14_wv = pd.read_csv('fy14_wv.csv')
fy14_wy = pd.read_csv('fy14_wy.csv')

#fy15
fy15_ak = pd.read_csv('fy15_ak.csv')
fy15_al = pd.read_csv('fy15_al.csv')
fy15_ar = pd.read_csv('fy15_ar.csv')
fy15_az = pd.read_csv('fy15_az.csv')
fy15_ca = pd.read_csv('fy15_ca.csv')
fy15_co = pd.read_csv('fy15_co.csv')
fy15_ct = pd.read_csv('fy15_ct.csv')
fy15_dc = pd.read_csv('fy15_dc.csv')
fy15_de = pd.read_csv('fy15_de.csv')
fy15_fl = pd.read_csv('fy15_fl.csv')
fy15_ga = pd.read_csv('fy15_ga.csv')
fy15_gu = pd.read_csv('fy15_gu.csv')
fy15_hi = pd.read_csv('fy15_hi.csv')
fy15_ia = pd.read_csv('fy15_ia.csv')
fy15_id = pd.read_csv('fy15_id.csv')
fy15_il = pd.read_csv('fy15_il.csv')
fy15_in = pd.read_csv('fy15_in.csv')
fy15_ks = pd.read_csv('fy15_ks.csv')
fy15_ky = pd.read_csv('fy15_ky.csv')
fy15_la = pd.read_csv('fy15_la.csv')
fy15_ma = pd.read_csv('fy15_ma.csv')
fy15_md = pd.read_csv('fy15_md.csv')
fy15_me = pd.read_csv('fy15_me.csv')
fy15_mi = pd.read_csv('fy15_mi.csv')
fy15_mn = pd.read_csv('fy15_mn.csv')
fy15_mo = pd.read_csv('fy15_mo.csv')
fy15_ms = pd.read_csv('fy15_ms.csv')
fy15_mt = pd.read_csv('fy15_mt.csv')
fy15_nc = pd.read_csv('fy15_nc.csv')
fy15_nd = pd.read_csv('fy15_nd.csv')
fy15_ne = pd.read_csv('fy15_ne.csv')
fy15_nh = pd.read_csv('fy15_nh.csv')
fy15_nj = pd.read_csv('fy15_nj.csv')
fy15_nm = pd.read_csv('fy15_nm.csv')
fy15_nv = pd.read_csv('fy15_nv.csv')
fy15_ny = pd.read_csv('fy15_ny.csv')
fy15_oh = pd.read_csv('fy15_oh.csv')
fy15_ok = pd.read_csv('fy15_ok.csv')
fy15_or = pd.read_csv('fy15_or.csv')
fy15_pa = pd.read_csv('fy15_pa.csv')
fy15_pr = pd.read_csv('fy15_pr.csv')
fy15_ri = pd.read_csv('fy15_ri.csv')
fy15_sc = pd.read_csv('fy15_sc.csv')
fy15_sd = pd.read_csv('fy15_sd.csv')
fy15_tn = pd.read_csv('fy15_tn.csv')
fy15_tx = pd.read_csv('fy15_tx.csv')
fy15_ut = pd.read_csv('fy15_ut.csv')
fy15_va = pd.read_csv('fy15_va.csv')
fy15_vt = pd.read_csv('fy15_vt.csv')
fy15_wa = pd.read_csv('fy15_wa.csv')
fy15_wi = pd.read_csv('fy15_wi.csv')
fy15_wv = pd.read_csv('fy15_wv.csv')
fy15_wy = pd.read_csv('fy15_wy.csv')

#fy16
fy16_ak = pd.read_csv('fy16_ak.csv')
fy16_al = pd.read_csv('fy16_al.csv')
fy16_ar = pd.read_csv('fy16_ar.csv')
fy16_az = pd.read_csv('fy16_az.csv')
fy16_ca = pd.read_csv('fy16_ca.csv')
fy16_co = pd.read_csv('fy16_co.csv')
fy16_ct = pd.read_csv('fy16_ct.csv')
fy16_dc = pd.read_csv('fy16_dc.csv')
fy16_de = pd.read_csv('fy16_de.csv')
fy16_fl = pd.read_csv('fy16_fl.csv')
fy16_ga = pd.read_csv('fy16_ga.csv')
fy16_gu = pd.read_csv('fy16_gu.csv')
fy16_hi = pd.read_csv('fy16_hi.csv')
fy16_ia = pd.read_csv('fy16_ia.csv')
fy16_id = pd.read_csv('fy16_id.csv')
fy16_il = pd.read_csv('fy16_il.csv')
fy16_in = pd.read_csv('fy16_in.csv')
fy16_ks = pd.read_csv('fy16_ks.csv')
fy16_ky = pd.read_csv('fy16_ky.csv')
fy16_la = pd.read_csv('fy16_la.csv')
fy16_ma = pd.read_csv('fy16_ma.csv')
fy16_md = pd.read_csv('fy16_md.csv')
fy16_me = pd.read_csv('fy16_me.csv')
fy16_mi = pd.read_csv('fy16_mi.csv')
fy16_mn = pd.read_csv('fy16_mn.csv')
fy16_mo = pd.read_csv('fy16_mo.csv')
fy16_ms = pd.read_csv('fy16_ms.csv')
fy16_mt = pd.read_csv('fy16_mt.csv')
fy16_nc = pd.read_csv('fy16_nc.csv')
fy16_nd = pd.read_csv('fy16_nd.csv')
fy16_ne = pd.read_csv('fy16_ne.csv')
fy16_nh = pd.read_csv('fy16_nh.csv')
fy16_nj = pd.read_csv('fy16_nj.csv')
fy16_nm = pd.read_csv('fy16_nm.csv')
fy16_nv = pd.read_csv('fy16_nv.csv')
fy16_ny = pd.read_csv('fy16_ny.csv')
fy16_oh = pd.read_csv('fy16_oh.csv')
fy16_ok = pd.read_csv('fy16_ok.csv')
fy16_or = pd.read_csv('fy16_or.csv')
fy16_pa = pd.read_csv('fy16_pa.csv')
fy16_pr = pd.read_csv('fy16_pr.csv')
fy16_ri = pd.read_csv('fy16_ri.csv')
fy16_sc = pd.read_csv('fy16_sc.csv')
fy16_sd = pd.read_csv('fy16_sd.csv')
fy16_tn = pd.read_csv('fy16_tn.csv')
fy16_tx = pd.read_csv('fy16_tx.csv')
fy16_ut = pd.read_csv('fy16_ut.csv')
fy16_va = pd.read_csv('fy16_va.csv')
fy16_vt = pd.read_csv('fy16_vt.csv')
fy16_wa = pd.read_csv('fy16_wa.csv')
fy16_wi = pd.read_csv('fy16_wi.csv')
fy16_wv = pd.read_csv('fy16_wv.csv')
fy16_wy = pd.read_csv('fy16_wy.csv')

# %%
#Generate lists
FY_14_LIST=[
    fy14_ak,fy14_al,fy14_ar,fy14_az,fy14_ca,fy14_co,fy14_ct,fy14_dc,fy14_de,fy14_fl,fy14_ga,fy14_hi,fy14_ia,
    fy14_id,fy14_il,fy14_in,fy14_ks,fy14_ky,fy14_la,fy14_ma,fy14_md,fy14_me,fy14_mi,fy14_mn,fy14_mo,fy14_ms,fy14_mt,
    fy14_nc,fy14_nd,fy14_ne,fy14_nh,fy14_nj,fy14_nm,fy14_nv,fy14_ny,fy14_oh,fy14_ok,fy14_or,fy14_pa,fy14_pr,fy14_ri,
    fy14_sc,fy14_sd,fy14_tn,fy14_tx,fy14_ut,fy14_va,fy14_vt,fy14_wa,fy14_wi,fy14_wv,fy14_wy
]
FY_15_LIST=[
    fy15_ak,fy15_al,fy15_ar,fy15_az,fy15_ca,fy15_co,fy15_ct,fy15_dc,fy15_de,fy15_fl,fy15_ga,fy15_gu,fy15_hi,fy15_ia,
    fy15_id,fy15_il,fy15_in,fy15_ks,fy15_ky,fy15_la,fy15_ma,fy15_md,fy15_me,fy15_mi,fy15_mn,fy15_mo,fy15_ms,fy15_mt,
    fy15_nc,fy15_nd,fy15_ne,fy15_nh,fy15_nj,fy15_nm,fy15_nv,fy15_ny,fy15_oh,fy15_ok,fy15_or,fy15_pa,fy15_pr,fy15_ri,
    fy15_sc,fy15_sd,fy15_tn,fy15_tx,fy15_ut,fy15_va,fy15_vt,fy15_wa,fy15_wi,fy15_wv,fy15_wy
]
FY_16_LIST=[
    fy16_ak,fy16_al,fy16_ar,fy16_az,fy16_ca,fy16_co,fy16_ct,fy16_dc,fy16_de,fy16_fl,fy16_ga,fy16_gu,fy16_hi,fy16_ia,
    fy16_id,fy16_il,fy16_in,fy16_ks,fy16_ky,fy16_la,fy16_ma,fy16_md,fy16_me,fy16_mi,fy16_mn,fy16_mo,fy16_ms,fy16_mt,
    fy16_nc,fy16_nd,fy16_ne,fy16_nh,fy16_nj,fy16_nm,fy16_nv,fy16_ny,fy16_oh,fy16_ok,fy16_or,fy16_pa,fy16_pr,fy16_ri,
    fy16_sc,fy16_sd,fy16_tn,fy16_tx,fy16_ut,fy16_va,fy16_vt,fy16_wa,fy16_wi,fy16_wv,fy16_wy 
]
ALL_YEARS = [fy14_ak,fy14_al,fy14_ar,fy14_az,fy14_ca,fy14_co,fy14_ct,fy14_dc,fy14_de,fy14_fl,fy14_ga,fy14_gu,fy14_hi,fy14_ia,
    fy14_id,fy14_il,fy14_in,fy14_ks,fy14_ky,fy14_la,fy14_ma,fy14_md,fy14_me,fy14_mi,fy14_mn,fy14_mo,fy14_ms,fy14_mt,
    fy14_nc,fy14_nd,fy14_ne,fy14_nh,fy14_nj,fy14_nm,fy14_nv,fy14_ny,fy14_oh,fy14_ok,fy14_or,fy14_pa,fy14_pr,fy14_ri,
    fy14_sc,fy14_sd,fy14_tn,fy14_tx,fy14_ut,fy14_va,fy14_vt,fy14_wa,fy14_wi,fy14_wv,fy14_wy,fy15_ak,fy15_al,fy15_ar,fy15_az,fy15_ca,fy15_co,fy15_ct,fy15_dc,fy15_de,fy15_fl,fy15_ga,fy15_gu,fy15_hi,fy15_ia,
    fy15_id,fy15_il,fy15_in,fy15_ks,fy15_ky,fy15_la,fy15_ma,fy15_md,fy15_me,fy15_mi,fy15_mn,fy15_mo,fy15_ms,fy15_mt,
    fy15_nc,fy15_nd,fy15_ne,fy15_nh,fy15_nj,fy15_nm,fy15_nv,fy15_ny,fy15_oh,fy15_ok,fy15_or,fy15_pa,fy15_pr,fy15_ri,
    fy15_sc,fy15_sd,fy15_tn,fy15_tx,fy15_ut,fy15_va,fy15_vt,fy15_wa,fy15_wi,fy15_wv,fy15_wy,fy16_ak,fy16_al,fy16_ar,fy16_az,fy16_ca,fy16_co,fy16_ct,fy16_dc,fy16_de,fy16_fl,fy16_ga,fy16_gu,fy16_hi,fy16_ia,
    fy16_id,fy16_il,fy16_in,fy16_ks,fy16_ky,fy16_la,fy16_ma,fy16_md,fy16_me,fy16_mi,fy16_mn,fy16_mo,fy16_ms,fy16_mt,
    fy16_nc,fy16_nd,fy16_ne,fy16_nh,fy16_nj,fy16_nm,fy16_nv,fy16_ny,fy16_oh,fy16_ok,fy16_or,fy16_pa,fy16_pr,fy16_ri,
    fy16_sc,fy16_sd,fy16_tn,fy16_tx,fy16_ut,fy16_va,fy16_vt,fy16_wa,fy16_wi,fy16_wv,fy16_wy]

# %%
fy14_ak,
fy14_al,
fy14_ar,
fy14_az,
fy14_ca,
fy14_co,
fy14_ct,
fy14_dc,
fy14_de,
fy14_fl,
fy14_ga,
fy14_gu,
fy14_hi,
fy14_ia,
fy14_id,
fy14_il,
fy14_in,
fy14_ks,
fy14_ky,
fy14_la,
fy14_ma,
fy14_md,
fy14_me,
fy14_mi,
fy14_mn,
fy14_mo,
fy14_ms,
fy14_mt,
fy14_nc,
fy14_nd,
fy14_ne,
fy14_nh,
fy14_nj,
fy14_nm,
fy14_nv,
fy14_ny,
fy14_oh,
fy14_ok,
fy14_or,
fy14_pa,
fy14_pr,
fy14_ri,
fy14_sc,
fy14_sd,
fy14_tn,
fy14_tx,
fy14_ut,
fy14_va,
fy14_vt,
fy14_wa,
fy14_wi,
fy14_wv,
fy14_wy,

#fy15
fy15_ak,
fy15_al,
fy15_ar,
fy15_az,
fy15_ca,
fy15_co,
fy15_ct,
fy15_dc,
fy15_de,
fy15_fl,
fy15_ga,
fy15_gu,
fy15_hi,
fy15_ia,
fy15_id,
fy15_il,
fy15_in,
fy15_ks,
fy15_ky,
fy15_la,
fy15_ma,
fy15_md,
fy15_me,
fy15_mi,
fy15_mn,
fy15_mo,
fy15_ms,
fy15_mt,
fy15_nc,
fy15_nd,
fy15_ne,
fy15_nh,
fy15_nj,
fy15_nm,
fy15_nv,
fy15_ny,
fy15_oh,
fy15_ok,
fy15_or,
fy15_pa,
fy15_pr,
fy15_ri,
fy15_sc,
fy15_sd,
fy15_tn,
fy15_tx,
fy15_ut,
fy15_va,
fy15_vt,
fy15_wa,
fy15_wi,
fy15_wv,
fy15_wy,

#fy16
fy16_ak,
fy16_al,
fy16_ar,
fy16_az,
fy16_ca,
fy16_co,
fy16_ct,
fy16_dc,
fy16_de,
fy16_fl,
fy16_ga,
fy16_gu,
fy16_hi,
fy16_ia,
fy16_id,
fy16_il,
fy16_in,
fy16_ks,
fy16_ky,
fy16_la,
fy16_ma,
fy16_md,
fy16_me,
fy16_mi,
fy16_mn,
fy16_mo,
fy16_ms,
fy16_mt,
fy16_nc,
fy16_nd,
fy16_ne,
fy16_nh,
fy16_nj,
fy16_nm,
fy16_nv,
fy16_ny,
fy16_oh,
fy16_ok,
fy16_or,
fy16_pa,
fy16_pr,
fy16_ri,
fy16_sc,
fy16_sd,
fy16_tn,
fy16_tx,
fy16_ut,
fy16_va,
fy16_vt,
fy16_wa,
fy16_wi,
fy16_wv,
fy16_wy
# Out:
#     Year State County/ Congressional District Veteran Population*  \
# 0     16    WY                         ALBANY               2,223
# 1     16    WY                       BIG HORN                 900
# 2     16    WY                       CAMPBELL               2,862
# 3     16    WY                         CARBON               1,096
# 4     16    WY                       CONVERSE               1,210
# 5     16    WY                          CROOK                 574
# 6     16    WY                        FREMONT               2,852
# 7     16    WY                         GOSHEN               1,219
# 8     16    WY                    HOT SPRINGS                 519
# 9     16    WY                        JOHNSON                 900
# 10    16    WY                        LARAMIE              11,861
# 11    16    WY                        LINCOLN                 989
# 12    16    WY                        NATRONA               6,286
# 13    16    WY                       NIOBRARA                 242
# 14    16    WY                           PARK               2,654
# 15    16    WY                         PLATTE                 865
# 16    16    WY                       SHERIDAN               2,814
# 17    16    WY                       SUBLETTE                 576
# 18    16    WY                     SWEETWATER               3,218
# 19    16    WY                          TETON                 961
# 20    16    WY                          UINTA               1,255
# 21    16    WY                       WASHAKIE                 734
# 22    16    WY                         WESTON                 662
# 23    16    WY               WYOMING (Totals)              47,472
# 24    16    WY                CONG. DIST (01)              47,472
# 25    16    WY               WYOMING (Totals)              47,472
#
#    Total Expenditure Compensation & Pension Construction  \
# 0           $18,891                 $8,629           $-
# 1            $5,399                 $2,683           $-
# 2           $17,785                 $7,808           $-
# 3            $7,680                 $3,536           $-
# 4            $5,535                 $2,935           $-
# 5            $5,936                 $2,002           $-
# 6           $20,694                $10,695           $-
# 7            $9,007                 $4,369           $-
# 8            $3,742                 $1,549           $-
# 9           $10,301                 $3,406           $-
# 10         $144,110                $58,441       $3,214
# 11           $5,648                 $2,964           $-
# 12          $33,044                $16,833           $-
# 13           $1,410                   $615           $-
# 14          $17,738                 $9,115           $-
# 15           $7,538                 $3,278           $-
# 16          $59,597                $15,613         $761
# 17           $2,950                 $1,705           $-
# 18          $17,384                 $8,088           $-
# 19           $2,559                 $1,517           $-
# 20           $8,831                 $4,143           $-
# 21           $3,188                 $1,575           $-
# 22           $5,391                 $2,170           $-
# 23         $414,358               $173,669       $3,975
# 24         $414,358               $173,669       $3,975
# 25         $414,358               $173,669       $3,975
#
#    Education & Vocational Rehabilitation/ Employment Loan Guaranty#  \
# 0                                            $3,757             $-
# 1                                              $265             $-
# 2                                              $915             $-
# 3                                              $326             $-
# 4                                              $175             $-
# 5                                               $97             $-
# 6                                              $594             $-
# 7                                              $191             $-
# 8                                               $52             $-
# 9                                              $131             $-
# 10                                           $7,812             $-
# 11                                             $215             $-
# 12                                           $1,910             $-
# 13                                              $77             $-
# 14                                             $762             $-
# 15                                             $188             $-
# 16                                             $811             $-
# 17                                             $127             $-
# 18                                             $710             $-
# 19                                             $131             $-
# 20                                             $187             $-
# 21                                             $227             $-
# 22                                              $85             $-
# 23                                          $19,743             $-
# 24                                          $19,743             $-
# 25                                          $19,743             $-
#
#    General Operating Expenses Insurance & Indemnities Medical Care  \
# 0                         $-                    $141       $6,364
# 1                         $-                     $22       $2,429
# 2                         $-                    $129       $8,933
# 3                         $-                     $14       $3,803
# 4                         $-                     $52       $2,373
# 5                         $-                      $2       $3,835
# 6                         $-                    $217       $9,188
# 7                         $-                     $43       $4,404
# 8                         $-                     $21       $2,120
# 9                         $-                     $35       $6,728
# 10                    $1,093                    $914      $72,635
# 11                        $-                     $37       $2,432
# 12                        $-                    $556      $13,746
# 13                        $-                      $0         $718
# 14                        $-                    $135       $7,726
# 15                        $-                     $88       $3,983
# 16                      $615                     $80      $41,717
# 17                        $-                     $25       $1,093
# 18                        $-                     $43       $8,544
# 19                        $-                      $8         $903
# 20                        $-                     $31       $4,470
# 21                        $-                     $44       $1,342
# 22                        $-                      $6       $3,131
# 23                    $1,708                  $2,645     $212,618
# 24                    $1,708                  $2,645     $212,618
# 25                    $1,708                  $2,645     $212,618
#
#    Unique Patients**
# 0                791
# 1                392
# 2              1,131
# 3                415
# 4                342
# 5                316
# 6              1,277
# 7                446
# 8                223
# 9                461
# 10             4,948
# 11               405
# 12             1,915
# 13                88
# 14             1,054
# 15               380
# 16             1,992
# 17               187
# 18             1,035
# 19               159
# 20               407
# 21               244
# 22               288
# 23            18,896
# 24            18,896
# 25            18,896

# %%
fy16_mn.head(100)
# Out:
#     Year State County/ Congressional District Veteran Population*  \
# 0     16    MN                         AITKIN               1,874
# 1     16    MN                          ANOKA              22,462
# 2     16    MN                         BECKER               3,058
# 3     16    MN                       BELTRAMI               3,111
# 4     16    MN                         BENTON               3,012
# 5     16    MN                      BIG STONE                 448
# 6     16    MN                     BLUE EARTH               3,740
# 7     16    MN                          BROWN               1,893
# 8     16    MN                        CARLTON               2,882
# 9     16    MN                         CARVER               4,685
# 10    16    MN                           CASS               3,023
# 11    16    MN                       CHIPPEWA                 822
# 12    16    MN                        CHISAGO               3,995
# 13    16    MN                           CLAY               3,858
# 14    16    MN                     CLEARWATER                 875
# 15    16    MN                           COOK                 458
# 16    16    MN                     COTTONWOOD                 817
# 17    16    MN                      CROW WING               5,861
# 18    16    MN                         DAKOTA              25,689
# 19    16    MN                          DODGE               1,349
# 20    16    MN                        DOUGLAS               3,095
# 21    16    MN                      FARIBAULT               1,183
# 22    16    MN                       FILLMORE               1,483
# 23    16    MN                       FREEBORN               2,541
# 24    16    MN                        GOODHUE               3,738
# 25    16    MN                          GRANT                 508
# 26    16    MN                       HENNEPIN              56,055
# 27    16    MN                        HOUSTON               1,391
# 28    16    MN                        HUBBARD               2,062
# 29    16    MN                         ISANTI               2,871
# ..   ...   ...                            ...                 ...
# 67    16    MN                         ROSEAU               1,150
# 68    16    MN                      ST. LOUIS              16,024
# 69    16    MN                          SCOTT               6,722
# 70    16    MN                      SHERBURNE               5,892
# 71    16    MN                         SIBLEY                 894
# 72    16    MN                        STEARNS              10,246
# 73    16    MN                         STEELE               2,485
# 74    16    MN                        STEVENS                 557
# 75    16    MN                          SWIFT                 683
# 76    16    MN                           TODD               1,925
# 77    16    MN                       TRAVERSE                 329
# 78    16    MN                        WABASHA               1,833
# 79    16    MN                         WADENA               1,225
# 80    16    MN                         WASECA               1,277
# 81    16    MN                     WASHINGTON              14,467
# 82    16    MN                       WATONWAN                 797
# 83    16    MN                         WILKIN                 459
# 84    16    MN                         WINONA               2,889
# 85    16    MN                         WRIGHT               7,823
# 86    16    MN                YELLOW MEDICINE                 768
# 87    16    MN             MINNESOTA (Totals)             337,362
# 88    16    MN                CONG. DIST (01)              44,452
# 89    16    MN                CONG. DIST (02)              42,290
# 90    16    MN                CONG. DIST (03)              36,402
# 91    16    MN                CONG. DIST (04)              34,036
# 92    16    MN                CONG. DIST (05)              30,306
# 93    16    MN                CONG. DIST (06)              44,105
# 94    16    MN                CONG. DIST (07)              48,717
# 95    16    MN                CONG. DIST (08)              57,053
# 96    16    MN             MINNESOTA (Totals)             337,362
#
#    Total Expenditure Compensation & Pension Construction  \
# 0           $16,258                 $8,411           $-
# 1          $154,458                $72,221           $-
# 2           $21,976                $11,233           $-
# 3           $29,936                $16,757           $-
# 4           $30,893                $11,098           $-
# 5            $3,556                 $2,279           $-
# 6           $29,313                $14,600           $-
# 7           $15,630                 $8,764           $-
# 8           $24,671                $15,286           $-
# 9           $24,736                $12,303           $-
# 10          $28,742                $15,270           $-
# 11           $6,937                 $2,983           $-
# 12          $33,356                $17,066           $-
# 13          $37,348                $15,578           $-
# 14           $8,232                 $3,717           $-
# 15           $3,168                 $1,886           $-
# 16           $5,334                 $3,007           $-
# 17          $57,135                $31,301           $-
# 18         $190,506                $88,389           $-
# 19           $6,872                 $3,633           $-
# 20          $27,505                $14,144           $-
# 21           $8,245                 $4,159           $-
# 22           $8,951                 $5,234           $-
# 23          $18,419                 $8,269           $-
# 24          $21,892                $11,106           $-
# 25           $4,566                 $2,650           $-
# 26         $491,631               $159,137         $411
# 27           $9,310                 $5,434           $-
# 28          $17,434                 $9,446           $-
# 29          $23,491                $11,012           $-
# ..               ...                    ...          ...
# 67           $6,209                 $3,251           $-
# 68         $109,475                $63,492           $-
# 69          $53,805                $24,310           $-
# 70          $58,139                $29,792           $-
# 71           $7,403                 $3,609           $-
# 72         $161,921                $55,184      $12,153
# 73          $13,806                 $7,512           $-
# 74           $3,022                 $1,810           $-
# 75           $6,192                 $3,156           $-
# 76          $17,235                 $7,221           $-
# 77           $2,456                 $1,438           $-
# 78          $14,012                 $7,818           $-
# 79          $16,245                 $9,969           $-
# 80           $8,999                 $4,520           $-
# 81          $94,879                $47,712           $-
# 82           $6,075                 $3,103           $-
# 83           $3,766                 $1,509           $-
# 84          $17,972                 $8,686           $-
# 85          $55,938                $26,712           $-
# 86           $7,098                 $3,423           $-
# 87       $2,677,849             $1,225,675      $12,564
# 88         $274,863               $144,538           $-
# 89         $304,374               $142,391           $-
# 90         $212,125                $92,704           $-
# 91         $234,620               $104,856           $-
# 92         $353,981               $101,095         $411
# 93         $410,644               $172,438      $12,118
# 94         $399,446               $198,646          $32
# 95         $487,796               $269,007           $3
# 96       $2,677,849             $1,225,675      $12,564
#
#    Education & Vocational Rehabilitation/ Employment Loan Guaranty#  \
# 0                                              $259             $-
# 1                                            $9,469             $-
# 2                                              $424             $-
# 3                                            $1,178             $-
# 4                                              $692             $-
# 5                                               $97             $-
# 6                                            $2,381             $-
# 7                                              $566             $-
# 8                                            $1,126             $-
# 9                                            $1,572             $-
# 10                                             $464             $-
# 11                                             $144             $-
# 12                                           $1,871             $-
# 13                                           $2,021             $-
# 14                                             $147             $-
# 15                                              $41             $-
# 16                                              $38             $-
# 17                                           $1,572             $-
# 18                                          $14,683             $-
# 19                                             $437             $-
# 20                                             $637             $-
# 21                                             $283             $-
# 22                                             $392             $-
# 23                                             $280             $-
# 24                                           $1,438             $-
# 25                                              $66             $-
# 26                                          $28,741             $-
# 27                                             $424             $-
# 28                                             $422             $-
# 29                                             $744             $-
# ..                                               ...            ...
# 67                                             $230             $-
# 68                                           $7,049             $-
# 69                                           $5,429             $-
# 70                                           $3,118             $-
# 71                                             $155             $-
# 72                                           $3,894             $-
# 73                                             $708             $-
# 74                                             $155             $-
# 75                                             $231             $-
# 76                                             $200             $-
# 77                                              $17             $-
# 78                                             $361             $-
# 79                                             $397             $-
# 80                                             $447             $-
# 81                                           $8,870             $-
# 82                                             $152             $-
# 83                                              $87             $-
# 84                                           $1,219             $-
# 85                                           $3,485             $-
# 86                                             $142             $-
# 87                                         $138,626             $-
# 88                                          $14,763             $-
# 89                                          $23,515             $-
# 90                                          $15,642             $-
# 91                                          $19,613             $-
# 92                                          $17,635             $-
# 93                                          $18,526             $-
# 94                                          $11,493             $-
# 95                                          $17,437             $-
# 96                                         $138,626             $-
#
#    General Operating Expenses Insurance & Indemnities Medical Care  \
# 0                         $-                     $53       $7,534
# 1                         $-                  $1,948      $70,819
# 2                         $-                    $116      $10,203
# 3                         $-                    $242      $11,760
# 4                         $-                    $160      $18,944
# 5                         $-                    $130       $1,050
# 6                         $-                    $541      $11,791
# 7                         $-                    $389       $5,911
# 8                         $-                    $113       $8,145
# 9                         $-                    $343      $10,517
# 10                        $-                    $155      $12,854
# 11                        $-                     $17       $3,793
# 12                        $-                    $371      $14,048
# 13                        $-                    $667      $19,081
# 14                        $-                     $24       $4,345
# 15                        $-                     $12       $1,229
# 16                        $-                     $87       $2,202
# 17                        $-                    $437      $23,825
# 18                        $-                  $2,917      $84,517
# 19                        $-                     $76       $2,727
# 20                        $-                    $380      $12,344
# 21                        $-                     $40       $3,764
# 22                        $-                     $60       $3,265
# 23                        $-                    $117       $9,754
# 24                        $-                    $252       $9,096
# 25                        $-                     $22       $1,828
# 26                   $84,867                  $8,261     $210,215
# 27                        $-                    $164       $3,289
# 28                        $-                    $133       $7,433
# 29                        $-                     $90      $11,646
# ..                        ...                     ...          ...
# 67                        $-                     $36       $2,692
# 68                        $-                  $1,492      $37,442
# 69                        $-                    $420      $23,646
# 70                        $-                    $424      $24,806
# 71                        $-                     $95       $3,543
# 72                    $1,261                    $840      $88,589
# 73                        $-                    $254       $5,332
# 74                        $-                     $17       $1,040
# 75                        $-                     $69       $2,736
# 76                        $-                     $30       $9,784
# 77                        $-                     $50         $951
# 78                        $-                    $199       $5,634
# 79                        $-                    $404       $5,475
# 80                        $-                    $198       $3,834
# 81                        $-                  $1,643      $36,655
# 82                        $-                     $80       $2,739
# 83                        $-                     $86       $2,083
# 84                        $-                    $221       $7,847
# 85                        $-                    $523      $25,219
# 86                        $-                    $165       $3,369
# 87                   $86,128                 $34,596   $1,180,261
# 88                        $-                  $4,638     $110,924
# 89                        $-                  $4,167     $134,301
# 90                        $-                  $4,273      $99,505
# 91                        $-                  $4,474     $105,677
# 92                   $84,867                  $4,929     $145,043
# 93                    $1,261                  $3,432     $202,870
# 94                        $-                  $4,384     $184,891
# 95                        $-                  $4,299     $197,050
# 96                   $86,128                 $34,596   $1,180,261
#
#    Unique Patients**
# 0                912
# 1              7,301
# 2              1,204
# 3              1,367
# 4              1,534
# 5                227
# 6              1,348
# 7                838
# 8              1,028
# 9              1,236
# 10             1,566
# 11               466
# 12             1,287
# 13             1,681
# 14               414
# 15               123
# 16               333
# 17             2,934
# 18             7,402
# 19               386
# 20             1,506
# 21               412
# 22               475
# 23             1,132
# 24             1,039
# 25               210
# 26            15,754
# 27               637
# 28               885
# 29             1,228
# ..               ...
# 67               387
# 68             5,768
# 69             2,274
# 70             2,593
# 71               428
# 72             5,870
# 73               705
# 74               219
# 75               331
# 76             1,096
# 77               147
# 78               693
# 79               584
# 80               457
# 81             3,545
# 82               358
# 83               177
# 84               999
# 85             2,665
# 86               380
# 87           118,886
# 88            14,863
# 89            12,421
# 90             9,895
# 91             8,852
# 92             9,221
# 93            17,558
# 94            22,027
# 95            24,049
# 96           118,886
#
# [97 rows x 13 columns]

# %%
sorted_fy16_mn = fy16_mn.sort_values(['Veteran Population*'], ascending=[1])

# %%
fy16_mn.head(100)
# Out:
#     Year State County/ Congressional District Veteran Population*  \
# 0     16    MN                         AITKIN               1,874
# 1     16    MN                          ANOKA              22,462
# 2     16    MN                         BECKER               3,058
# 3     16    MN                       BELTRAMI               3,111
# 4     16    MN                         BENTON               3,012
# 5     16    MN                      BIG STONE                 448
# 6     16    MN                     BLUE EARTH               3,740
# 7     16    MN                          BROWN               1,893
# 8     16    MN                        CARLTON               2,882
# 9     16    MN                         CARVER               4,685
# 10    16    MN                           CASS               3,023
# 11    16    MN                       CHIPPEWA                 822
# 12    16    MN                        CHISAGO               3,995
# 13    16    MN                           CLAY               3,858
# 14    16    MN                     CLEARWATER                 875
# 15    16    MN                           COOK                 458
# 16    16    MN                     COTTONWOOD                 817
# 17    16    MN                      CROW WING               5,861
# 18    16    MN                         DAKOTA              25,689
# 19    16    MN                          DODGE               1,349
# 20    16    MN                        DOUGLAS               3,095
# 21    16    MN                      FARIBAULT               1,183
# 22    16    MN                       FILLMORE               1,483
# 23    16    MN                       FREEBORN               2,541
# 24    16    MN                        GOODHUE               3,738
# 25    16    MN                          GRANT                 508
# 26    16    MN                       HENNEPIN              56,055
# 27    16    MN                        HOUSTON               1,391
# 28    16    MN                        HUBBARD               2,062
# 29    16    MN                         ISANTI               2,871
# ..   ...   ...                            ...                 ...
# 67    16    MN                         ROSEAU               1,150
# 68    16    MN                      ST. LOUIS              16,024
# 69    16    MN                          SCOTT               6,722
# 70    16    MN                      SHERBURNE               5,892
# 71    16    MN                         SIBLEY                 894
# 72    16    MN                        STEARNS              10,246
# 73    16    MN                         STEELE               2,485
# 74    16    MN                        STEVENS                 557
# 75    16    MN                          SWIFT                 683
# 76    16    MN                           TODD               1,925
# 77    16    MN                       TRAVERSE                 329
# 78    16    MN                        WABASHA               1,833
# 79    16    MN                         WADENA               1,225
# 80    16    MN                         WASECA               1,277
# 81    16    MN                     WASHINGTON              14,467
# 82    16    MN                       WATONWAN                 797
# 83    16    MN                         WILKIN                 459
# 84    16    MN                         WINONA               2,889
# 85    16    MN                         WRIGHT               7,823
# 86    16    MN                YELLOW MEDICINE                 768
# 87    16    MN             MINNESOTA (Totals)             337,362
# 88    16    MN                CONG. DIST (01)              44,452
# 89    16    MN                CONG. DIST (02)              42,290
# 90    16    MN                CONG. DIST (03)              36,402
# 91    16    MN                CONG. DIST (04)              34,036
# 92    16    MN                CONG. DIST (05)              30,306
# 93    16    MN                CONG. DIST (06)              44,105
# 94    16    MN                CONG. DIST (07)              48,717
# 95    16    MN                CONG. DIST (08)              57,053
# 96    16    MN             MINNESOTA (Totals)             337,362
#
#    Total Expenditure Compensation & Pension Construction  \
# 0           $16,258                 $8,411           $-
# 1          $154,458                $72,221           $-
# 2           $21,976                $11,233           $-
# 3           $29,936                $16,757           $-
# 4           $30,893                $11,098           $-
# 5            $3,556                 $2,279           $-
# 6           $29,313                $14,600           $-
# 7           $15,630                 $8,764           $-
# 8           $24,671                $15,286           $-
# 9           $24,736                $12,303           $-
# 10          $28,742                $15,270           $-
# 11           $6,937                 $2,983           $-
# 12          $33,356                $17,066           $-
# 13          $37,348                $15,578           $-
# 14           $8,232                 $3,717           $-
# 15           $3,168                 $1,886           $-
# 16           $5,334                 $3,007           $-
# 17          $57,135                $31,301           $-
# 18         $190,506                $88,389           $-
# 19           $6,872                 $3,633           $-
# 20          $27,505                $14,144           $-
# 21           $8,245                 $4,159           $-
# 22           $8,951                 $5,234           $-
# 23          $18,419                 $8,269           $-
# 24          $21,892                $11,106           $-
# 25           $4,566                 $2,650           $-
# 26         $491,631               $159,137         $411
# 27           $9,310                 $5,434           $-
# 28          $17,434                 $9,446           $-
# 29          $23,491                $11,012           $-
# ..               ...                    ...          ...
# 67           $6,209                 $3,251           $-
# 68         $109,475                $63,492           $-
# 69          $53,805                $24,310           $-
# 70          $58,139                $29,792           $-
# 71           $7,403                 $3,609           $-
# 72         $161,921                $55,184      $12,153
# 73          $13,806                 $7,512           $-
# 74           $3,022                 $1,810           $-
# 75           $6,192                 $3,156           $-
# 76          $17,235                 $7,221           $-
# 77           $2,456                 $1,438           $-
# 78          $14,012                 $7,818           $-
# 79          $16,245                 $9,969           $-
# 80           $8,999                 $4,520           $-
# 81          $94,879                $47,712           $-
# 82           $6,075                 $3,103           $-
# 83           $3,766                 $1,509           $-
# 84          $17,972                 $8,686           $-
# 85          $55,938                $26,712           $-
# 86           $7,098                 $3,423           $-
# 87       $2,677,849             $1,225,675      $12,564
# 88         $274,863               $144,538           $-
# 89         $304,374               $142,391           $-
# 90         $212,125                $92,704           $-
# 91         $234,620               $104,856           $-
# 92         $353,981               $101,095         $411
# 93         $410,644               $172,438      $12,118
# 94         $399,446               $198,646          $32
# 95         $487,796               $269,007           $3
# 96       $2,677,849             $1,225,675      $12,564
#
#    Education & Vocational Rehabilitation/ Employment Loan Guaranty#  \
# 0                                              $259             $-
# 1                                            $9,469             $-
# 2                                              $424             $-
# 3                                            $1,178             $-
# 4                                              $692             $-
# 5                                               $97             $-
# 6                                            $2,381             $-
# 7                                              $566             $-
# 8                                            $1,126             $-
# 9                                            $1,572             $-
# 10                                             $464             $-
# 11                                             $144             $-
# 12                                           $1,871             $-
# 13                                           $2,021             $-
# 14                                             $147             $-
# 15                                              $41             $-
# 16                                              $38             $-
# 17                                           $1,572             $-
# 18                                          $14,683             $-
# 19                                             $437             $-
# 20                                             $637             $-
# 21                                             $283             $-
# 22                                             $392             $-
# 23                                             $280             $-
# 24                                           $1,438             $-
# 25                                              $66             $-
# 26                                          $28,741             $-
# 27                                             $424             $-
# 28                                             $422             $-
# 29                                             $744             $-
# ..                                               ...            ...
# 67                                             $230             $-
# 68                                           $7,049             $-
# 69                                           $5,429             $-
# 70                                           $3,118             $-
# 71                                             $155             $-
# 72                                           $3,894             $-
# 73                                             $708             $-
# 74                                             $155             $-
# 75                                             $231             $-
# 76                                             $200             $-
# 77                                              $17             $-
# 78                                             $361             $-
# 79                                             $397             $-
# 80                                             $447             $-
# 81                                           $8,870             $-
# 82                                             $152             $-
# 83                                              $87             $-
# 84                                           $1,219             $-
# 85                                           $3,485             $-
# 86                                             $142             $-
# 87                                         $138,626             $-
# 88                                          $14,763             $-
# 89                                          $23,515             $-
# 90                                          $15,642             $-
# 91                                          $19,613             $-
# 92                                          $17,635             $-
# 93                                          $18,526             $-
# 94                                          $11,493             $-
# 95                                          $17,437             $-
# 96                                         $138,626             $-
#
#    General Operating Expenses Insurance & Indemnities Medical Care  \
# 0                         $-                     $53       $7,534
# 1                         $-                  $1,948      $70,819
# 2                         $-                    $116      $10,203
# 3                         $-                    $242      $11,760
# 4                         $-                    $160      $18,944
# 5                         $-                    $130       $1,050
# 6                         $-                    $541      $11,791
# 7                         $-                    $389       $5,911
# 8                         $-                    $113       $8,145
# 9                         $-                    $343      $10,517
# 10                        $-                    $155      $12,854
# 11                        $-                     $17       $3,793
# 12                        $-                    $371      $14,048
# 13                        $-                    $667      $19,081
# 14                        $-                     $24       $4,345
# 15                        $-                     $12       $1,229
# 16                        $-                     $87       $2,202
# 17                        $-                    $437      $23,825
# 18                        $-                  $2,917      $84,517
# 19                        $-                     $76       $2,727
# 20                        $-                    $380      $12,344
# 21                        $-                     $40       $3,764
# 22                        $-                     $60       $3,265
# 23                        $-                    $117       $9,754
# 24                        $-                    $252       $9,096
# 25                        $-                     $22       $1,828
# 26                   $84,867                  $8,261     $210,215
# 27                        $-                    $164       $3,289
# 28                        $-                    $133       $7,433
# 29                        $-                     $90      $11,646
# ..                        ...                     ...          ...
# 67                        $-                     $36       $2,692
# 68                        $-                  $1,492      $37,442
# 69                        $-                    $420      $23,646
# 70                        $-                    $424      $24,806
# 71                        $-                     $95       $3,543
# 72                    $1,261                    $840      $88,589
# 73                        $-                    $254       $5,332
# 74                        $-                     $17       $1,040
# 75                        $-                     $69       $2,736
# 76                        $-                     $30       $9,784
# 77                        $-                     $50         $951
# 78                        $-                    $199       $5,634
# 79                        $-                    $404       $5,475
# 80                        $-                    $198       $3,834
# 81                        $-                  $1,643      $36,655
# 82                        $-                     $80       $2,739
# 83                        $-                     $86       $2,083
# 84                        $-                    $221       $7,847
# 85                        $-                    $523      $25,219
# 86                        $-                    $165       $3,369
# 87                   $86,128                 $34,596   $1,180,261
# 88                        $-                  $4,638     $110,924
# 89                        $-                  $4,167     $134,301
# 90                        $-                  $4,273      $99,505
# 91                        $-                  $4,474     $105,677
# 92                   $84,867                  $4,929     $145,043
# 93                    $1,261                  $3,432     $202,870
# 94                        $-                  $4,384     $184,891
# 95                        $-                  $4,299     $197,050
# 96                   $86,128                 $34,596   $1,180,261
#
#    Unique Patients**
# 0                912
# 1              7,301
# 2              1,204
# 3              1,367
# 4              1,534
# 5                227
# 6              1,348
# 7                838
# 8              1,028
# 9              1,236
# 10             1,566
# 11               466
# 12             1,287
# 13             1,681
# 14               414
# 15               123
# 16               333
# 17             2,934
# 18             7,402
# 19               386
# 20             1,506
# 21               412
# 22               475
# 23             1,132
# 24             1,039
# 25               210
# 26            15,754
# 27               637
# 28               885
# 29             1,228
# ..               ...
# 67               387
# 68             5,768
# 69             2,274
# 70             2,593
# 71               428
# 72             5,870
# 73               705
# 74               219
# 75               331
# 76             1,096
# 77               147
# 78               693
# 79               584
# 80               457
# 81             3,545
# 82               358
# 83               177
# 84               999
# 85             2,665
# 86               380
# 87           118,886
# 88            14,863
# 89            12,421
# 90             9,895
# 91             8,852
# 92             9,221
# 93            17,558
# 94            22,027
# 95            24,049
# 96           118,886
#
# [97 rows x 13 columns]

# %%
cut_mn16 = pd.DataFrame(fy16_mn, columns=['Veteran Population*','Education & Vocational Rehabilitation/ Employment'])

# %% [markdown]
# data = MINNESOTA (Totals) =  (‘Education & Vocational Rehabilitation/ Employment’ X 1000 ) / ‘Veteran Population*’
#
# for totals get last row of df df.tail(1)
# for cong. dist cut out of df
#
#
# - make list size 159
#
# - make iterating func to go through list and get last row using tail func
#
#     - in that func avg_dol_per_vet = df[(‘Education & Vocational Rehabilitation/ Employment’ X 1000 )] / df[‘Veteran Population*’]

# %%
cut_mn16.tail(1)
# Out:
#    Veteran Population* Education & Vocational Rehabilitation/ Employment
# 96             337,362                                         $138,626

# %%
# avg edu $ spent per vet in mn 16
#avg_dollar = (cut_mn[‘Education & Vocational Rehabilitation/ Employment’] X 1000 ) / cut_mn16[‘Veteran Population*’]
mn16_tail = cut_mn16.tail(1)
vet_pop = mn16_tail.iloc[0]['Veteran Population*']
vet_pop = int(vet_pop.replace(',', ''))
edu_dol = mn16_tail.iloc[0]['Education & Vocational Rehabilitation/ Employment']
edu_dol = edu_dol.replace(',', '')
edu_dol = int(edu_dol.replace('$', ''))
avg_dol_per_vet = (edu_dol * 1000) / vet_pop
avg_dol_per_vet = round(avg_dol_per_vet)
print(" vet pop: ", vet_pop, "\n", "edu_dol (in thousands): ", edu_dol, "\n", "avg per vet:",   avg_dol_per_vet)
# Out:
#  vet pop:  337362
#  edu_dol (in thousands):  138626
#  avg per vet: 411

# %%
# func educational spending per veteran in state
# param df 
# return average amount spent on education benefits 
# per veteran in state 
def edu_spend(df):
    #tail = df.tail(1)
    vet_pop = df.iloc[0]['Veteran Population*']
    #vet_pop_type = type(vet_pop)
    #vet_pop = vet_pop.replace(',', '')
    #vet_pop = int(vet_pop)
    edu_dol = df.iloc[0]['Education & Vocational Rehabilitation/ Employment']
#     edu_dol = edu_dol.replace(',', '')
#     edu_dol = edu_dol.replace('$', '')
#     edu_dol = int(edu_dol.replace('$', ''))
    avg_dol_per_vet = (edu_dol * 1000) / vet_pop
    avg_dol_per_vet = round(avg_dol_per_vet)
    #print(" vet pop: ", vet_pop, "\n", "edu_dol (in thousands): ", edu_dol, "\n", "avg per vet:",   avg_dol_per_vet)
    return avg_dol_per_vet

# %%
total = 0
for i in FY_14_LIST:
    total += 1
    edu_spend(i)
    print(total)
    #print( total,"edu per vet" , edu_spend(i))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-248-2d599924c5db> in <module>()
#       2 for i in FY_14_LIST:
#       3     total += 1
# ----> 4     edu_spend(i)
#       5     print(total)
#       6     #print( total,"edu per vet" , edu_spend(i))
#
# <ipython-input-247-06b1117a0830> in edu_spend(df)
#      13 #     edu_dol = edu_dol.replace('$', '')
#      14 #     edu_dol = int(edu_dol.replace('$', ''))
# ---> 15     avg_dol_per_vet = (edu_dol * 1000) / vet_pop
#      16     avg_dol_per_vet = round(avg_dol_per_vet)
#      17     #print(" vet pop: ", vet_pop, "\n", "edu_dol (in thousands): ", edu_dol, "\n", "avg per vet:",   avg_dol_per_vet)
#
# TypeError: unsupported operand type(s) for /: 'str' and 'str'

# %%
# DF for FY14 Educational Benefit per vet by state
edu_spend_per_state_14 =  pd.DataFrame(columns=['state', 'educational amount per vet in $'])
edu_spend_per_state_14.head()
# Out:
# Empty DataFrame
# Columns: [state, educational amount per vet in $]
# Index: []

# %%
edu_spend(fy16_gu)
# Out:
# class is:  <class 'float'>
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-225-942d795bb5a0> in <module>()
# ----> 1 edu_spend(fy16_gu)
#
# <ipython-input-201-818ccae6a52f> in edu_spend(df)
#       9     if (vet_pop_type!= "<class 'str'>"):
#      10         print("class is: ", vet_pop_type)
# ---> 11         vet_pop = vet_pop.replace(',', '')
#      12         vet_pop = int(vet_pop)
#      13     edu_dol = tail.iloc[0]['Education & Vocational Rehabilitation/ Employment']
#
# AttributeError: 'float' object has no attribute 'replace'

# %%
print(fy14_gu.iloc[0]['Veteran Population*']
)
print(type(fy14_gu.iloc[0]['Veteran Population*']))
# Out:
# 9,453
# <class 'str'>

# %%
fy14_all = pd.read_csv('sheenas_data_for_graphing.csv')
fy14_all.head()
# Out:
#                                                State  Veteran Population*  \
# 0                                            Alabama               413618
# 1                                             Alaska                73397
# 2  Arizona                                       ...               532206
# 3  Arkansas                                      ...               249274
# 4                                         California              1851470
#
#    Total Expenditure  Education Spending Percent  Compensation & Pension  \
# 0            3191317                           7                 1875091
# 1             552280                          14                  244437
# 2            3607036                          11                 1666170
# 3            2143834                           4                 1055813
# 4           14318281                          13                 6376052
#
#    Compensation & Pension Percentage  \
# 0                                 59
# 1                                 44
# 2                                 46
# 3                                 49
# 4                                 45
#
#    Education & Vocational Rehabilitation/ Employment  \
# 0                                             225325
# 1                                              74731
# 2                                             410041
# 3                                              95186
# 4                                            1848364
#
#    Education Spending Per Veteran
# 0                             545
# 1                            1018
# 2                             770
# 3                             382
# 4                             998

# %%
edu_spend(fy14_all)
# Out:
# 545.0

# %%
fig, axes = plt.subplots(nrows=3, ncols=1)
for i, rows(fy14_all.columns):
    fy14_all[c].plot(kind='bar', ax=axes[i], figsize=(12, 10), title=c)
# Out:
#   File "<ipython-input-303-f0dcd602e312>", line 2
#     for i, rows(fy14_all.columns):
#                                  ^
# SyntaxError: invalid syntax

# %%
my_bins = range(0,53, 1)

fig, ax = plt.subplots(figsize=(8,4))

fy14_all.hist(column="Education Spending Per Veteran", ax=ax, bins=my_bins)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x115039da0>], dtype=object)

# %%
fy14_all.hist(x='State', y='Education Spending Per Veteran', kind ='bar')
#plt.axis('off')
plt.xticks([])
#plt.yticks([])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-305-a531f81a1983> in <module>()
# ----> 1 fy14_all.hist(x='State', y='Education Spending Per Veteran', kind ='bar')
#       2 #plt.axis('off')
#       3 plt.xticks([])
#       4 #plt.yticks([])
#
# /Users/ballerblue/anaconda/lib/python3.6/site-packages/pandas/plotting/_core.py in hist_frame(data, column, by, grid, xlabelsize, xrot, ylabelsize, yrot, ax, sharex, sharey, figsize, layout, bins, **kwds)
#    2128     for i, col in enumerate(_try_sort(data.columns)):
#    2129         ax = _axes[i]
# -> 2130         ax.hist(data[col].dropna().values, bins=bins, **kwds)
#    2131         ax.set_title(col)
#    2132         ax.grid(grid)
#
# /Users/ballerblue/anaconda/lib/python3.6/site-packages/matplotlib/__init__.py in inner(ax, *args, **kwargs)
#    1896                     warnings.warn(msg % (label_namer, func.__name__),
#    1897                                   RuntimeWarning, stacklevel=2)
# -> 1898             return func(ax, *args, **kwargs)
#    1899         pre_doc = inner.__doc__
#    1900         if pre_doc is None:
#
# TypeError: hist() got multiple values for argument 'x'

# %%
fig, ax = plt.subplots(figsize=(8,4))

fy14_all.hist(column="Education Spending Per Veteran", ax=ax)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x1156ea780>], dtype=object)

# %%
#val = fy14_all["Education Spending Per Veteran"]
#print(val)
fy14_all.head()
# Out:
#                                                State  Veteran Population*  \
# 0                                            Alabama               413618
# 1                                             Alaska                73397
# 2  Arizona                                       ...               532206
# 3  Arkansas                                      ...               249274
# 4                                         California              1851470
#
#    Total Expenditure  Education Spending Percent  Compensation & Pension  \
# 0            3191317                           7                 1875091
# 1             552280                          14                  244437
# 2            3607036                          11                 1666170
# 3            2143834                           4                 1055813
# 4           14318281                          13                 6376052
#
#    Compensation & Pension Percentage  \
# 0                                 59
# 1                                 44
# 2                                 46
# 3                                 49
# 4                                 45
#
#    Education & Vocational Rehabilitation/ Employment  \
# 0                                             225325
# 1                                              74731
# 2                                             410041
# 3                                              95186
# 4                                            1848364
#
#    Education Spending Per Veteran
# 0                             545
# 1                            1018
# 2                             770
# 3                             382
# 4                             998
